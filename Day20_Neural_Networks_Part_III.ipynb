# %% [markdown]
# <a href="https://colab.research.google.com/github/rashedalsharqi/cs-167-notes/blob/main/Day20_Neural_Networks_Part_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS167: Day20
# ## Neural Networks Part III
#
# #### CS167: Machine Learning, Spring 2023
#
# Tuesday, April 11th, 2023
#
# 📆 [Course Schedule](https://docs.google.com/spreadsheets/d/e/2PACX-1vSvFV5Mz0_YZE1d5r3gQ8IMktE4cBAsJIlP30cl2GhEpSO0J-YWV62QokSDz-OcOCsEmxMuKpY0kVlR/pubhtml?gid=0&single=true) | 🙋[PollEverywhere](https://pollev.com/meredithmoore011) | 📜 [Syllabus](https://analytics.drake.edu/~moore/cs167_s23_syllabus.html) | 📬 [CodePost Login](https://codepost.io/login)

# %% [markdown]
# # Admin Stuff

# %% [markdown]
# Grading--I owe you grades for:
# - Project #1
# - Quiz #2
# - Notebook #5

# %% [markdown]
# You should be working on:
# - [Notebook #6](https://classroom.github.com/a/pUdpmxBH) is released today, due April 17th by 11:59pm

# %% [markdown]
# # Announcement
#
# __Thursday 4/13__: We'll have guest speakers from Berkshire Hathaway
#
# <div>
# <img src="https://github.com/merriekay/S23-CS167-Notes/blob/main/images/berkshire_hathaway_energy.jpeg?raw=1" width=250/>
# </div>

# %% [markdown]
# ## Load your data:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas
path = '/content/drive/MyDrive/datasets/irisData.csv' #'/content/drive/MyDrive/CS167/datasets/irisData.csv'
data = pandas.read_csv(path)

# %% [markdown]
# ## Quick Review:

# %% [markdown]
# # Neural Network Summary
#
# Neural Networks are effective in __finding non-linear patterns__ in the training data.
# - can be applied to __regression__ or __classification__.
# - __backpropagation__ tunes the weights over a neural network using __gradient descent__ to iteratively reduce the error in the network.
# - __Overfitting__ the training data is common and is important to avoid.
# - The following parameters shoudl be tuned when using neural networks:
#     - number of epochs
#     - structure of the network (depth, width)
#     - activation function
#     - eta (learning rate)

# %% [markdown]
# # Training a Neural Network to Predict Taxi Fares:
#
# Download `taxi-fares.csv` from Blackboard and put it in your Google Drive. This data is from the New York City Taxi and LImousine Commision and includes data about taxi fares.
#
# Let's start by loading in our dataset and doing some pre-processing.

# %%
from math import sqrt
import pandas as pd

#load dataset
path = '/content/drive/MyDrive/datasets/taxi-fares.csv' #'/content/drive/MyDrive/CS167/datasets/taxi-fares.csv'
df = pd.read_csv(path, parse_dates=['pickup_datetime'])

# data prep
df = df[df['passenger_count'] == 1]
df = df.drop(['key', 'passenger_count'], axis=1)
 
for i, row in df.iterrows():
    dt = row['pickup_datetime']
    df.at[i, 'day_of_week'] = dt.weekday()
    df.at[i, 'pickup_time'] = dt.hour
    x = (row['dropoff_longitude'] - row['pickup_longitude']) * 54.6
    y = (row['dropoff_latitude'] - row['pickup_latitude']) * 69.0
    distance = sqrt(x**2 + y**2)
    df.at[i, 'distance'] = distance
 
df.drop(['pickup_datetime', 'pickup_longitude', 'pickup_latitude',
         'dropoff_longitude', 'dropoff_latitude'], axis=1, inplace=True)
 
df = df[(df['distance'] > 1.0) & (df['distance'] < 10.0)]
df = df[(df['fare_amount'] > 0.0) & (df['fare_amount'] < 50.0)]
df.head()
# Out:
#    fare_amount  day_of_week  pickup_time  distance
# 2          6.1          0.0         15.0  1.038136
# 4         10.5          5.0         10.0  2.924341
# 5         15.3          4.0         20.0  4.862893
# 8          7.7          5.0          1.0  2.603493
# 9          8.9          3.0         16.0  1.365739

# %% [markdown]
# ## 🙋 PollEverywhere

# %% [markdown]
# # Build Your Model:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
model = Sequential()
model.add(Dense(512, activation='relu', input_dim=3))
model.add(Dense(512, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mae', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               2048
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 265,217
# Trainable params: 265,217
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - What is the _depth_ of this model? 2
# - How many attributes are input to the model? 3
# - What is the _width_ of the hidden layers of this model? 512
# - What type of Gradient Descent is being used to train this model? atom
# - What metrics are we keeping track of?

# %% [markdown]
# # Now, let's train our model:

# %%
x = df.drop('fare_amount', axis=1)
y = df['fare_amount']

hist = model.fit(x, y, validation_split=0.2, epochs=50, batch_size=100)
# Out:
# Epoch 1/50
# 187/187 [==============================] - 6s 4ms/step - loss: 2.9105 - mae: 2.9105 - val_loss: 2.4022 - val_mae: 2.4022
# Epoch 2/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.4063 - mae: 2.4063 - val_loss: 2.3684 - val_mae: 2.3684
# Epoch 3/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3787 - mae: 2.3787 - val_loss: 2.3836 - val_mae: 2.3836
# Epoch 4/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3772 - mae: 2.3772 - val_loss: 2.3970 - val_mae: 2.3970
# Epoch 5/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3582 - mae: 2.3582 - val_loss: 2.3451 - val_mae: 2.3451
# Epoch 6/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3658 - mae: 2.3658 - val_loss: 2.3532 - val_mae: 2.3532
# Epoch 7/50
# 187/187 [==============================] - 1s 6ms/step - loss: 2.3722 - mae: 2.3722 - val_loss: 2.4206 - val_mae: 2.4206
# Epoch 8/50
# 187/187 [==============================] - 1s 6ms/step - loss: 2.3566 - mae: 2.3566 - val_loss: 2.5724 - val_mae: 2.5724
# Epoch 9/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3691 - mae: 2.3691 - val_loss: 2.3485 - val_mae: 2.3485
# Epoch 10/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3568 - mae: 2.3568 - val_loss: 2.3470 - val_mae: 2.3470
# Epoch 11/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3548 - mae: 2.3548 - val_loss: 2.3435 - val_mae: 2.3435
# Epoch 12/50
# 187/187 [==============================] - 1s 6ms/step - loss: 2.3457 - mae: 2.3457 - val_loss: 2.3299 - val_mae: 2.3299
# Epoch 13/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3443 - mae: 2.3443 - val_loss: 2.3754 - val_mae: 2.3754
# Epoch 14/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3479 - mae: 2.3479 - val_loss: 2.4890 - val_mae: 2.4890
# Epoch 15/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3366 - mae: 2.3366 - val_loss: 2.3271 - val_mae: 2.3271
# Epoch 16/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3368 - mae: 2.3368 - val_loss: 2.3405 - val_mae: 2.3405
# Epoch 17/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3310 - mae: 2.3310 - val_loss: 2.3512 - val_mae: 2.3512
# Epoch 18/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3339 - mae: 2.3339 - val_loss: 2.3298 - val_mae: 2.3298
# Epoch 19/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3276 - mae: 2.3276 - val_loss: 2.3524 - val_mae: 2.3524
# Epoch 20/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3539 - mae: 2.3539 - val_loss: 2.3331 - val_mae: 2.3331
# Epoch 21/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3383 - mae: 2.3383 - val_loss: 2.3238 - val_mae: 2.3238
# Epoch 22/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3200 - mae: 2.3200 - val_loss: 2.3192 - val_mae: 2.3192
# Epoch 23/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3188 - mae: 2.3188 - val_loss: 2.3239 - val_mae: 2.3239
# Epoch 24/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3326 - mae: 2.3326 - val_loss: 2.3015 - val_mae: 2.3015
# Epoch 25/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3319 - mae: 2.3319 - val_loss: 2.4313 - val_mae: 2.4313
# Epoch 26/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3392 - mae: 2.3392 - val_loss: 2.3246 - val_mae: 2.3246
# Epoch 27/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3190 - mae: 2.3190 - val_loss: 2.2964 - val_mae: 2.2964
# Epoch 28/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3215 - mae: 2.3215 - val_loss: 2.3262 - val_mae: 2.3262
# Epoch 29/50
# 187/187 [==============================] - 1s 6ms/step - loss: 2.3159 - mae: 2.3159 - val_loss: 2.2929 - val_mae: 2.2929
# Epoch 30/50
# 187/187 [==============================] - 1s 6ms/step - loss: 2.3225 - mae: 2.3225 - val_loss: 2.3419 - val_mae: 2.3419
# Epoch 31/50
# 187/187 [==============================] - 1s 6ms/step - loss: 2.3217 - mae: 2.3217 - val_loss: 2.2974 - val_mae: 2.2974
# Epoch 32/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.3158 - mae: 2.3158 - val_loss: 2.2991 - val_mae: 2.2991
# Epoch 33/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3157 - mae: 2.3157 - val_loss: 2.2948 - val_mae: 2.2948
# Epoch 34/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3269 - mae: 2.3269 - val_loss: 2.3196 - val_mae: 2.3196
# Epoch 35/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3111 - mae: 2.3111 - val_loss: 2.2958 - val_mae: 2.2958
# Epoch 36/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3035 - mae: 2.3035 - val_loss: 2.3017 - val_mae: 2.3017
# Epoch 37/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3088 - mae: 2.3088 - val_loss: 2.3131 - val_mae: 2.3131
# Epoch 38/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2971 - mae: 2.2971 - val_loss: 2.2945 - val_mae: 2.2945
# Epoch 39/50
# 187/187 [==============================] - 1s 3ms/step - loss: 2.3089 - mae: 2.3089 - val_loss: 2.2924 - val_mae: 2.2924
# Epoch 40/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3131 - mae: 2.3131 - val_loss: 2.3318 - val_mae: 2.3318
# Epoch 41/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3075 - mae: 2.3075 - val_loss: 2.2836 - val_mae: 2.2836
# Epoch 42/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3045 - mae: 2.3045 - val_loss: 2.3117 - val_mae: 2.3117
# Epoch 43/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3031 - mae: 2.3031 - val_loss: 2.2829 - val_mae: 2.2829
# Epoch 44/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2997 - mae: 2.2997 - val_loss: 2.3032 - val_mae: 2.3032
# Epoch 45/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.2953 - mae: 2.2953 - val_loss: 2.2942 - val_mae: 2.2942
# Epoch 46/50
# 187/187 [==============================] - 1s 6ms/step - loss: 2.3021 - mae: 2.3021 - val_loss: 2.3369 - val_mae: 2.3369
# Epoch 47/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.2999 - mae: 2.2999 - val_loss: 2.3311 - val_mae: 2.3311
# Epoch 48/50
# 187/187 [==============================] - 1s 6ms/step - loss: 2.2950 - mae: 2.2950 - val_loss: 2.2761 - val_mae: 2.2761
# Epoch 49/50
# 187/187 [==============================] - 1s 5ms/step - loss: 2.2992 - mae: 2.2992 - val_loss: 2.3037 - val_mae: 2.3037
# Epoch 50/50
# 187/187 [==============================] - 1s 4ms/step - loss: 2.3048 - mae: 2.3048 - val_loss: 2.2907 - val_mae: 2.2907

# %% [markdown]
# # And take a look at the results:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

err = hist.history['mae']
val_err = hist.history['val_mae']
epochs = range(1, len(err) + 1)

plt.plot(epochs, err, '-', label='Training MAE')
plt.plot(epochs, val_err, ':', label='Validation MAE')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(loc='upper right')
plt.plot()
# Out:
# []

# %% [markdown]
# # Last, but not least, let's make some predictions:

# %%
from sklearn.metrics import r2_score

r2_score(y, model.predict(x))
# Out:
# 729/729 [==============================] - 2s 2ms/step
# 0.7473983693443329

# %% [markdown]
# Estimate what it will cost to hire a taxi for a 2-mile trip at 5:00pm on a Friday afternoon:
# - day of the week `[ Monday:0, Tuesday:1, Wednesday:2, Thursday:3, Friday:4, Saturday:5, Sunday:6]`
# - time, military time
# - distance in miles

# %%
import numpy as np

# day of the week, time, and distance
model.predict(np.array([[4, 17, 2.0]]))
# Out:
# 1/1 [==============================] - 0s 47ms/step
# array([[10.943396]], dtype=float32)

# %% [markdown]
# # ✨ New Material

# %% [markdown]
# To talk about:
# - practicing building models
# - sensitive data
# - imbalanced datasets
# - saving and loading models

# %% [markdown]
# # Fraud Detection with Neural Networks
#
# Credit card companies use ML models to examine transactions in real time and identify ones that are likely to be fraudulent.
# - the features they use contain sensitive information (credit card numbers, purchase history, etc)
#
# ## 💬 Group Discussion:
# - the anonymity of the customers should be preserved somehow, while keeping as much data as possible. Any ideas how we might go about doing this?

# %% [markdown]
# > Go ahead and download the `creditcard.csv` file from Bb.
#
# - `Time` is the number of seconds elapsed since the first transaction
# - `Class` tells us whether the transaction is legitimate (0) or fraudulent (1)
# - `Amount` is the amount the transaction was for.
# - The other columns `V1` - `V28` were generated using PCA from information that isn't revelaed to us.

# %%
import pandas as pd

path = '/content/drive/MyDrive/datasets/creditcard.csv' # #'/content/drive/MyDrive/CS167/datasets/creditcard.csv'
df = pd.read_csv(path)
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %% [markdown]
# # Imbalanced Datasets:
#
# In the real world, we rarely get the privilege of working with nicely balanced datasets. This dataset is a great example of this.
#
# What do I mean by a __balanced dataset__?
# - relatively equal distribution of the classes we're trying to predict.
#
# How might we check to see if our dataset is balanced?

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# We'll use [`train_test_split`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)'s `stratify` parameter to ensure that the ratio of legimate and fraudulent transactions is consisten in the training and the testing dataset:

# %%
from sklearn.model_selection import train_test_split

x = df.drop(['Time', 'Class'], axis=1)
y = df['Class']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y, random_state=0)

# %% [markdown]
# # Exercise #1: Build our network
#
# What kind of machine learning are we doing here? Classifiation or regression?

# %% [markdown]
# Let's build a network that has:
# - `input_dim=29`
# - 1 hidden layer with 128 neurons
# - `relu` for the activation function of the hidden layer
# - a `Dense` output layer with a `sigmoid` activation function.
#
# when you're done, print out the summary of your model.

# %%
# your code here:
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential() 

#build your model here:
model = Sequential()
model.add(Dense(128, activation='relu', input_dim=29))
model.add(Dense(1, activation='sigmoid'))
model.compile( loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 128)               3840
#
#  dense_9 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3,969
# Trainable params: 3,969
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile your model with loss='binary_crossentropy', optimizer='adam', and metrics=['accuracy']
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# train your model for 10 epochs, with batch_size=100
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=10, batch_size=100)
# Out:
# Epoch 1/10
# 2279/2279 [==============================] - 10s 4ms/step - loss: 0.0233 - accuracy: 0.9986 - val_loss: 0.0086 - val_accuracy: 0.9993
# Epoch 2/10
# 2279/2279 [==============================] - 9s 4ms/step - loss: 0.0099 - accuracy: 0.9992 - val_loss: 0.0060 - val_accuracy: 0.9994
# Epoch 3/10
# 2279/2279 [==============================] - 10s 4ms/step - loss: 0.0105 - accuracy: 0.9993 - val_loss: 0.0048 - val_accuracy: 0.9994
# Epoch 4/10
# 2279/2279 [==============================] - 8s 4ms/step - loss: 0.0067 - accuracy: 0.9993 - val_loss: 0.0049 - val_accuracy: 0.9994
# Epoch 5/10
# 2279/2279 [==============================] - 11s 5ms/step - loss: 0.0096 - accuracy: 0.9993 - val_loss: 0.0045 - val_accuracy: 0.9993
# Epoch 6/10
# 2279/2279 [==============================] - 10s 4ms/step - loss: 0.0098 - accuracy: 0.9994 - val_loss: 0.0270 - val_accuracy: 0.9992
# Epoch 7/10
# 2279/2279 [==============================] - 8s 4ms/step - loss: 0.0077 - accuracy: 0.9994 - val_loss: 0.0060 - val_accuracy: 0.9993
# Epoch 8/10
# 2279/2279 [==============================] - 10s 4ms/step - loss: 0.0064 - accuracy: 0.9994 - val_loss: 0.0053 - val_accuracy: 0.9994
# Epoch 9/10
# 2279/2279 [==============================] - 10s 4ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.0046 - val_accuracy: 0.9994
# Epoch 10/10
# 2279/2279 [==============================] - 8s 4ms/step - loss: 0.0070 - accuracy: 0.9994 - val_loss: 0.0072 - val_accuracy: 0.9993

# %% [markdown]
# Plot the training accuracy and validation acuracy:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training accuracy')
plt.plot(epochs, val, ':', label='Validation accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# Visualize the results as a confusion matrix:

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import matplotlib.pyplot as plt

sns.reset_orig()
y_predicted = model.predict(x_test) > 0.5 # it will be 1 if > 0.5 and 0 otherwise
labels = ['Legitimate', 'Fraudulent']

cm = confusion_matrix(y_test, y_predicted, labels=df.Class.unique())
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labels)
disp.plot()
plt.show()
# Out:
# 1781/1781 [==============================] - 3s 1ms/step

# %% [markdown]
# Your results will vary, but in this example, the model caught 74 of 98 fraudulent cases, and missclassified 9 legitimate charges as fraudulent.
#
# What is the accuracy of fraudulent cases?

# %%
total_fraudulent = 24 + 74
correct = 74
correct / total_fraudulent
# Out:
# 0.7551020408163265

# %% [markdown]
# ## Things to consider:
#
# - how might we make predictions with this model?

# %% [markdown]
# # Multiclass Classification with Neural Networks:
#
# We just did an example where we were doing `binary classification`. What things do we need to change to be able to do `multiclass classification`?

# %% [markdown]
# - the output layer needs to contain _one neuron per output class_
# - the output layer should use _______ activation instead of `sigmoid`.
# - the loss function wil be `sparse_cateogrical_crossentropy`

# %% [markdown]
# ## Training a Neural Network to Recognize Faces
#
# We're going to use the [Labeled Faces in the Wild (LFW)](http://vis-www.cs.umass.edu/lfw/) dataset.
#
# We'll learn that Convolutional Neural Networks will be able to do a better job on this data than regular Neural networks. But let's give it a shot:

# %% [markdown]
# # Load the dataset:
#
# This dataset contains more than 13,000 facial images collected from tne internet.
#
# Of the more than 5000 people represented in the dataset 1680 have two or more facial images, while only five have 100 or more.
#
# We'll set the minimum number of faces per person to 100, which means that five sets of faces corresponding to five famous people will be imported.

# %%
import pandas as pd
from sklearn.datasets import fetch_lfw_people

faces = fetch_lfw_people(min_faces_per_person=100, slice_=None)
faces.images = faces.images[:, 35:97, 39:86]
faces.data = faces.images.reshape(faces.images.shape[0], faces.images.shape[1] * faces.images.shape[2])
image_count = faces.images.shape[0]
image_height = faces.images.shape[1]
image_width = faces.images.shape[2]
class_count = len(faces.target_names)

print(faces.target_names)
print(faces.images.shape)
# Out:
# ['Colin Powell' 'Donald Rumsfeld' 'George W Bush' 'Gerhard Schroeder'
#  'Tony Blair']
# (1140, 62, 47)

# %% [markdown]
# In total, 1140 facial images were loaded. AFter cropping, each image measures 47x 62 pixels for a total of 2914 pixels per image. That means we're workign with a dataset containing 2914 feature columns.
#
# Use the folloiwng code to show the first 24 images in the dataset and the poeple to whom the faces belong.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, 8, figsize=(18, 10))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gist_gray')
    axi.set(xticks=[], yticks=[], xlabel=faces.target_names[faces.target[i]])

# %% [markdown]
# ## 💬 Group Exercise
#
# Check the balance of the dataset:

# %% [markdown]
# The dataset is not very well balanced, and that's a concern because classification models are best trained with balanced datasets. Use the following code to build a dataset containing 100 images of each person.

# %%
import numpy as np

mask = np.zeros(faces.target.shape, dtype=bool)

for target in np.unique(faces.target):
    mask[np.where(faces.target == target)[0][:100]] = 1
    
x_faces = faces.data[mask]
y_faces = faces.target[mask]
x_faces.shape
# Out:
# (500, 2914)

# %% [markdown]
# ## Split the data for training and testing:

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x_faces, y_faces, train_size=0.8, stratify=y_faces, random_state=0)

# %% [markdown]
# ## Build and train a neural network:
#
# Start by using Keras to build and train an eural network containnig:
# - one hidden layer with 512 neurons.
# - `sparse_categorical_crossentropy` as the loss function
# - a `softmax` activation function on our output layer since this is a multiclass classification task
# -  `adam` as our optimization algorithm

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
 
model = Sequential()
# build your model here:
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 512)               1492480
#
#  dense_11 (Dense)            (None, 5)                 2565
#
# =================================================================
# Total params: 1,495,045
# Trainable params: 1,495,045
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, train your model:

# %%
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 16ms/step - loss: 3.3236 - accuracy: 0.1950 - val_loss: 1.7093 - val_accuracy: 0.2000
# Epoch 2/100
# 20/20 [==============================] - 0s 7ms/step - loss: 1.6325 - accuracy: 0.2900 - val_loss: 1.5627 - val_accuracy: 0.2700
# Epoch 3/100
# 20/20 [==============================] - 0s 7ms/step - loss: 1.4386 - accuracy: 0.3900 - val_loss: 1.4072 - val_accuracy: 0.4300
# Epoch 4/100
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3440 - accuracy: 0.4575 - val_loss: 1.3982 - val_accuracy: 0.3600
# Epoch 5/100
# 20/20 [==============================] - 0s 7ms/step - loss: 1.3162 - accuracy: 0.4725 - val_loss: 1.3707 - val_accuracy: 0.4500
# Epoch 6/100
# 20/20 [==============================] - 0s 9ms/step - loss: 1.2170 - accuracy: 0.5475 - val_loss: 1.3029 - val_accuracy: 0.4900
# Epoch 7/100
# 20/20 [==============================] - 0s 8ms/step - loss: 1.2113 - accuracy: 0.5175 - val_loss: 1.1653 - val_accuracy: 0.5900
# Epoch 8/100
# 20/20 [==============================] - 0s 7ms/step - loss: 1.0468 - accuracy: 0.6200 - val_loss: 1.0819 - val_accuracy: 0.5800
# Epoch 9/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.9875 - accuracy: 0.6375 - val_loss: 1.0660 - val_accuracy: 0.6300
# Epoch 10/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.9004 - accuracy: 0.7150 - val_loss: 0.9462 - val_accuracy: 0.6900
# Epoch 11/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.8379 - accuracy: 0.7650 - val_loss: 0.9685 - val_accuracy: 0.6700
# Epoch 12/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7754 - accuracy: 0.8125 - val_loss: 0.9158 - val_accuracy: 0.6400
# Epoch 13/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7783 - accuracy: 0.7625 - val_loss: 1.0829 - val_accuracy: 0.6100
# Epoch 14/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.7030 - accuracy: 0.7825 - val_loss: 1.0075 - val_accuracy: 0.6600
# Epoch 15/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6883 - accuracy: 0.8100 - val_loss: 0.9519 - val_accuracy: 0.6600
# Epoch 16/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6549 - accuracy: 0.7925 - val_loss: 0.7574 - val_accuracy: 0.7100
# Epoch 17/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5714 - accuracy: 0.8475 - val_loss: 0.7817 - val_accuracy: 0.7300
# Epoch 18/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5485 - accuracy: 0.8400 - val_loss: 1.0591 - val_accuracy: 0.6400
# Epoch 19/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5970 - accuracy: 0.7975 - val_loss: 0.7460 - val_accuracy: 0.7600
# Epoch 20/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5567 - accuracy: 0.8150 - val_loss: 0.7511 - val_accuracy: 0.7400
# Epoch 21/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4861 - accuracy: 0.8675 - val_loss: 0.9618 - val_accuracy: 0.6400
# Epoch 22/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4773 - accuracy: 0.8500 - val_loss: 0.8270 - val_accuracy: 0.7100
# Epoch 23/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5333 - accuracy: 0.8150 - val_loss: 0.9905 - val_accuracy: 0.5800
# Epoch 24/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.5230 - accuracy: 0.8450 - val_loss: 0.9265 - val_accuracy: 0.6500
# Epoch 25/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4776 - accuracy: 0.8300 - val_loss: 0.6542 - val_accuracy: 0.7500
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4121 - accuracy: 0.8775 - val_loss: 0.6650 - val_accuracy: 0.7500
# Epoch 27/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3665 - accuracy: 0.9075 - val_loss: 0.6719 - val_accuracy: 0.7700
# Epoch 28/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3256 - accuracy: 0.9150 - val_loss: 0.6304 - val_accuracy: 0.7600
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3558 - accuracy: 0.9025 - val_loss: 0.8679 - val_accuracy: 0.7000
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4303 - accuracy: 0.8450 - val_loss: 0.6842 - val_accuracy: 0.8000
# Epoch 31/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3618 - accuracy: 0.8875 - val_loss: 0.7708 - val_accuracy: 0.7300
# Epoch 32/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2957 - accuracy: 0.9250 - val_loss: 0.8664 - val_accuracy: 0.7500
# Epoch 33/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4053 - accuracy: 0.8800 - val_loss: 0.6248 - val_accuracy: 0.8000
# Epoch 34/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2652 - accuracy: 0.9475 - val_loss: 0.6119 - val_accuracy: 0.8000
# Epoch 35/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2525 - accuracy: 0.9350 - val_loss: 0.7376 - val_accuracy: 0.7700
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2501 - accuracy: 0.9525 - val_loss: 0.6549 - val_accuracy: 0.7400
# Epoch 37/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2440 - accuracy: 0.9500 - val_loss: 0.6050 - val_accuracy: 0.7800
# Epoch 38/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2426 - accuracy: 0.9325 - val_loss: 0.7895 - val_accuracy: 0.7300
# Epoch 39/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2928 - accuracy: 0.9025 - val_loss: 0.7276 - val_accuracy: 0.7400
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1970 - accuracy: 0.9650 - val_loss: 0.7754 - val_accuracy: 0.7200
# Epoch 41/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1911 - accuracy: 0.9600 - val_loss: 0.6014 - val_accuracy: 0.7900
# Epoch 42/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1879 - accuracy: 0.9500 - val_loss: 0.6349 - val_accuracy: 0.7700
# Epoch 43/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2741 - accuracy: 0.9150 - val_loss: 0.7454 - val_accuracy: 0.7300
# Epoch 44/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1952 - accuracy: 0.9600 - val_loss: 0.5616 - val_accuracy: 0.7900
# Epoch 45/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2262 - accuracy: 0.9325 - val_loss: 0.8702 - val_accuracy: 0.7300
# Epoch 46/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3058 - accuracy: 0.8950 - val_loss: 0.6016 - val_accuracy: 0.7900
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1801 - accuracy: 0.9625 - val_loss: 0.7099 - val_accuracy: 0.7400
# Epoch 48/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1526 - accuracy: 0.9700 - val_loss: 0.6207 - val_accuracy: 0.7700
# Epoch 49/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1687 - accuracy: 0.9600 - val_loss: 0.6659 - val_accuracy: 0.7600
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2406 - accuracy: 0.9275 - val_loss: 0.5576 - val_accuracy: 0.8300
# Epoch 51/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1365 - accuracy: 0.9725 - val_loss: 0.6463 - val_accuracy: 0.8100
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1600 - accuracy: 0.9700 - val_loss: 0.8378 - val_accuracy: 0.7500
# Epoch 53/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1656 - accuracy: 0.9575 - val_loss: 0.6361 - val_accuracy: 0.7400
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1758 - accuracy: 0.9450 - val_loss: 0.8553 - val_accuracy: 0.6800
# Epoch 55/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1126 - accuracy: 0.9800 - val_loss: 0.6077 - val_accuracy: 0.7900
# Epoch 56/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9950 - val_loss: 0.7379 - val_accuracy: 0.7600
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1359 - accuracy: 0.9675 - val_loss: 0.5324 - val_accuracy: 0.8100
# Epoch 58/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2306 - accuracy: 0.9200 - val_loss: 0.6011 - val_accuracy: 0.7600
# Epoch 59/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1544 - accuracy: 0.9700 - val_loss: 0.7450 - val_accuracy: 0.7300
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.9700 - val_loss: 0.5590 - val_accuracy: 0.8000
# Epoch 61/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.9800 - val_loss: 0.5770 - val_accuracy: 0.8200
# Epoch 62/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1141 - accuracy: 0.9750 - val_loss: 0.6879 - val_accuracy: 0.7800
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0949 - accuracy: 0.9925 - val_loss: 0.5491 - val_accuracy: 0.8000
# Epoch 64/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0883 - accuracy: 0.9875 - val_loss: 0.5218 - val_accuracy: 0.8000
# Epoch 65/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0814 - accuracy: 0.9900 - val_loss: 0.5416 - val_accuracy: 0.8100
# Epoch 66/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9900 - val_loss: 0.7401 - val_accuracy: 0.7600
# Epoch 67/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.9925 - val_loss: 0.6289 - val_accuracy: 0.7700
# Epoch 68/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1262 - accuracy: 0.9675 - val_loss: 0.8430 - val_accuracy: 0.7000
# Epoch 69/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2196 - accuracy: 0.9225 - val_loss: 1.5993 - val_accuracy: 0.5800
# Epoch 70/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2076 - accuracy: 0.9125 - val_loss: 0.9284 - val_accuracy: 0.7400
# Epoch 71/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1693 - accuracy: 0.9325 - val_loss: 0.8078 - val_accuracy: 0.8000
# Epoch 72/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1687 - accuracy: 0.9450 - val_loss: 1.0039 - val_accuracy: 0.7700
# Epoch 73/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1114 - accuracy: 0.9675 - val_loss: 0.6108 - val_accuracy: 0.7900
# Epoch 74/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0697 - accuracy: 0.9900 - val_loss: 0.6895 - val_accuracy: 0.7800
# Epoch 75/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0597 - accuracy: 0.9925 - val_loss: 0.6571 - val_accuracy: 0.8300
# Epoch 76/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0589 - accuracy: 0.9950 - val_loss: 0.6245 - val_accuracy: 0.7700
# Epoch 77/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0606 - accuracy: 0.9925 - val_loss: 0.6222 - val_accuracy: 0.7500
# Epoch 78/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1071 - accuracy: 0.9575 - val_loss: 1.1230 - val_accuracy: 0.7100
# Epoch 79/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1431 - accuracy: 0.9475 - val_loss: 0.8820 - val_accuracy: 0.7500
# Epoch 80/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0778 - accuracy: 0.9800 - val_loss: 0.5642 - val_accuracy: 0.8100
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9975 - val_loss: 0.8217 - val_accuracy: 0.7800
# Epoch 82/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0324 - accuracy: 1.0000 - val_loss: 0.5937 - val_accuracy: 0.8300
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.6228 - val_accuracy: 0.8100
# Epoch 84/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.5729 - val_accuracy: 0.8200
# Epoch 85/100
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.6531 - val_accuracy: 0.8000
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 1.0000 - val_loss: 0.5752 - val_accuracy: 0.8300
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 0.9950 - val_loss: 0.5881 - val_accuracy: 0.8000
# Epoch 88/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.6392 - val_accuracy: 0.8400
# Epoch 89/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.5918 - val_accuracy: 0.8200
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.6643 - val_accuracy: 0.8100
# Epoch 91/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.7843 - val_accuracy: 0.7900
# Epoch 92/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 1.0000 - val_loss: 0.6450 - val_accuracy: 0.8100
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 1.0000 - val_loss: 0.6640 - val_accuracy: 0.8300
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.6122 - val_accuracy: 0.8100
# Epoch 95/100
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0226 - accuracy: 1.0000 - val_loss: 0.6867 - val_accuracy: 0.8200
# Epoch 96/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 1.0000 - val_loss: 0.6219 - val_accuracy: 0.8100
# Epoch 97/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.6564 - val_accuracy: 0.8300
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.5895 - val_accuracy: 0.8100
# Epoch 99/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.6596 - val_accuracy: 0.8200
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.6711 - val_accuracy: 0.7900

# %% [markdown]
# Plot the training and validation accuracy:

# %%
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# And... finally, use the test data to generate a confusion matrix to visualize how the network performs.

# %%
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
import sklearn
print(sklearn.__version__)

sns.reset_orig()
y_pred = model.predict(x_test)

cm = confusion_matrix(y_test, y_pred.argmax(axis=1))
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=faces.target_names)
disp.plot()
# Out:
# 1.2.2
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
# # Keras Callbacks:
#
# Want to check in on your network while it's training? Keras's [_callbacks API_](https://keras.io/api/callbacks/) allows us to do so

# %% [markdown]
# Let's demo the callbacks API using MNIST, a very common computer vision dataset of handwritten digit recognition.

# %%
from tensorflow.keras.datasets import mnist

(train_images, y_train), (test_images, y_test) = mnist.load_data()
print('train_images: ' + str(train_images.shape))
print('y_train: ' + str(y_train.shape))
print('test_images: ' + str(test_images.shape))
print('y_test: ' + str(y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# train_images: (60000, 28, 28)
# y_train: (60000,)
# test_images: (10000, 28, 28)
# y_test: (10000,)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.tick_params(axis='both', which='both', bottom=False, top=False, left=False, right=False, labelbottom=False, labelleft=False)
plt.imshow(train_images[0], cmap=plt.cm.gray_r)

# %% [markdown]
# Plot the first 50 images from MNIST:

# %%
fig, axes = plt.subplots(5, 10, figsize=(12, 7), subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(train_images[i], cmap=plt.cm.gray_r)
    ax.text(0.45, 1.05, str(y_train[i]), transform=ax.transAxes)

# %% [markdown]
# ## Check to make sure it's balanced:

# %%
plt.xticks([])
plt.hist(y_train, rwidth=0.9)
# Out:
# (array([5923., 6742., 5958., 6131., 5842., 5421., 5918., 6265., 5851.,
#         5949.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Prepare the input data by flattening the pixel arrays and normalizing the pixel valuse by dividing thben by 255.

# %%
x_train = train_images.reshape(60000, 28 * 28) / 255
x_test = test_images.reshape(10000, 28 * 28) / 255

# %% [markdown]
# Create a neural network with a `softmax` output layer for the classification:

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(128, activation='relu', input_dim=28 * 28))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               100480
#
#  dense_13 (Dense)            (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Call `fit` to train the model. Stop training if the validation accuracy fails to imporve for 5 consecutive epochs, and reduce the learning rate if the validation accuracy fails to imporve for 3 consecutive epochs.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stop = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=3)

hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=50,
                 callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/100
# 1200/1200 [==============================] - 6s 4ms/step - loss: 0.2933 - accuracy: 0.9165 - val_loss: 0.1615 - val_accuracy: 0.9528 - lr: 0.0010
# Epoch 2/100
# 1200/1200 [==============================] - 3s 3ms/step - loss: 0.1310 - accuracy: 0.9616 - val_loss: 0.1186 - val_accuracy: 0.9646 - lr: 0.0010
# Epoch 3/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0909 - accuracy: 0.9730 - val_loss: 0.0889 - val_accuracy: 0.9753 - lr: 0.0010
# Epoch 4/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0686 - accuracy: 0.9796 - val_loss: 0.0873 - val_accuracy: 0.9737 - lr: 0.0010
# Epoch 5/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0548 - accuracy: 0.9836 - val_loss: 0.0814 - val_accuracy: 0.9760 - lr: 0.0010
# Epoch 6/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0437 - accuracy: 0.9865 - val_loss: 0.0843 - val_accuracy: 0.9738 - lr: 0.0010
# Epoch 7/100
# 1200/1200 [==============================] - 3s 3ms/step - loss: 0.0352 - accuracy: 0.9888 - val_loss: 0.0871 - val_accuracy: 0.9736 - lr: 0.0010
# Epoch 8/100
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0283 - accuracy: 0.9915 - val_loss: 0.0746 - val_accuracy: 0.9779 - lr: 0.0010
# Epoch 9/100
# 1200/1200 [==============================] - 3s 3ms/step - loss: 0.0230 - accuracy: 0.9936 - val_loss: 0.0793 - val_accuracy: 0.9769 - lr: 0.0010
# Epoch 10/100
# 1200/1200 [==============================] - 5s 4ms/step - loss: 0.0191 - accuracy: 0.9944 - val_loss: 0.0781 - val_accuracy: 0.9786 - lr: 0.0010
# Epoch 11/100
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0156 - accuracy: 0.9956 - val_loss: 0.0779 - val_accuracy: 0.9771 - lr: 0.0010
# Epoch 12/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0144 - accuracy: 0.9956 - val_loss: 0.0842 - val_accuracy: 0.9765 - lr: 0.0010
# Epoch 13/100
# 1200/1200 [==============================] - 3s 3ms/step - loss: 0.0105 - accuracy: 0.9971 - val_loss: 0.0998 - val_accuracy: 0.9737 - lr: 0.0010
# Epoch 14/100
# 1200/1200 [==============================] - 3s 3ms/step - loss: 0.0050 - accuracy: 0.9991 - val_loss: 0.0788 - val_accuracy: 0.9790 - lr: 5.0000e-04
# Epoch 15/100
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.0796 - val_accuracy: 0.9796 - lr: 5.0000e-04
# Epoch 16/100
# 1200/1200 [==============================] - 3s 3ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0823 - val_accuracy: 0.9796 - lr: 5.0000e-04
# Epoch 17/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.0802 - val_accuracy: 0.9799 - lr: 5.0000e-04
# Epoch 18/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0806 - val_accuracy: 0.9802 - lr: 5.0000e-04
# Epoch 19/100
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0887 - val_accuracy: 0.9797 - lr: 5.0000e-04
# Epoch 20/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.0871 - val_accuracy: 0.9801 - lr: 5.0000e-04
# Epoch 21/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0950 - val_accuracy: 0.9794 - lr: 5.0000e-04
# Epoch 22/100
# 1200/1200 [==============================] - 4s 4ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.0832 - val_accuracy: 0.9816 - lr: 2.5000e-04
# Epoch 23/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 6.6312e-04 - accuracy: 1.0000 - val_loss: 0.0855 - val_accuracy: 0.9814 - lr: 2.5000e-04
# Epoch 24/100
# 1200/1200 [==============================] - 3s 3ms/step - loss: 5.6714e-04 - accuracy: 1.0000 - val_loss: 0.0866 - val_accuracy: 0.9809 - lr: 2.5000e-04
# Epoch 25/100
# 1200/1200 [==============================] - 3s 3ms/step - loss: 5.3272e-04 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9811 - lr: 2.5000e-04
# Epoch 26/100
# 1200/1200 [==============================] - 5s 4ms/step - loss: 4.0781e-04 - accuracy: 1.0000 - val_loss: 0.0895 - val_accuracy: 0.9807 - lr: 1.2500e-04
# Epoch 27/100
# 1200/1200 [==============================] - 4s 3ms/step - loss: 3.6534e-04 - accuracy: 1.0000 - val_loss: 0.0901 - val_accuracy: 0.9815 - lr: 1.2500e-04

# %%
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []
